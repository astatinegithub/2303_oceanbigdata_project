# %% [markdown]
# ## 해양열파 관련 정보 조사 --> json

# %%
import json
# 한반도 주변 해양열파 이벤트 데이터베이스
# 해양열파 정의: 과거 30년 평균 대비 90백분위 초과하여 5일 이상 지속되는 극한 수온 현상

marine_heatwave_events = {
    'event1': {
        'location': {'lat': 37.5, 'lon': 129.5},
        'area': '동해 중부 해역 부근',
        'period': {'start_date': '2024-06-01', 'end_date': '2024-11-11'},
        'features': [
            '164일간 지속된 극한 해양열파',
            '한반도 주변 2024년 최장 기록',
            '여름철부터 가을철까지 지속',
            '동해 전체 해역에 광범위하게 영향',
            '수산업 및 해양생태계에 큰 영향'
        ],
        'sources': [
            'https://www.nifs.go.kr/page?id=red_tide_news',
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf'
        ]
    },
    
    'event2': {
        'location': {'lat': 36.5, 'lon': 125.5},
        'area': '황해 중부 해역 부근',
        'period': {'start_date': '2024-07-15', 'end_date': '2024-08-05'},
        'features': [
            '22일간 지속된 해양열파',
            '황해 특유의 얕은 수심으로 인한 급속 승온',
            '여름철 집중 발생',
            '연안어업에 직접적 영향',
            '중국 연안과 연결된 광역 현상'
        ],
        'sources': [
            'https://www.nifs.go.kr/page?id=red_tide_news',
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf'
        ]
    },
    
    'event3': {
        'location': {'lat': 33.0, 'lon': 126.0},
        'area': '동중국해 북부 해역 부근',
        'period': {'start_date': '2024-08-10', 'end_date': '2024-08-25'},
        'features': [
            '16일간 지속된 해양열파',
            '동중국해 북쪽 경계 지역 발생',
            '쿠로시오 해류와 연관된 현상',
            '제주도 남쪽 해역 포함',
            '아열대 해양환경 특성 반영'
        ],
        'sources': [
            'https://www.nifs.go.kr/page?id=red_tide_news',
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf'
        ]
    },
    
    'event4': {
        'location': {'lat': 38.0, 'lon': 130.0},
        'area': '동해 북부 해역 부근',
        'period': {'start_date': '2021-07-20', 'end_date': '2021-08-08'},
        'features': [
            '20일간 지속된 해양열파',
            '2021년 여름철 대표 해양열파 이벤트',
            '동해 북쪽 해역 집중 발생',
            '러시아 연해주 인근까지 확장',
            '냉수성 어종 서식지 영향'
        ],
        'sources': [
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf',
            'https://www.nifs.go.kr/page?id=red_tide_news'
        ]
    },
    
    'event5': {
        'location': {'lat': 35.0, 'lon': 128.0},
        'area': '동아시아 해역 부근',
        'period': {'start_date': '2023-04-15', 'end_date': '2024-01-08'},
        'features': [
            '268일간 지속된 초장기 해양열파',
            '한반도 주변 해역 역사상 최장 기록',
            '동아시아 전체 해역 광범위 영향',
            '봄철부터 다음해 겨울까지 지속',
            '기후변화의 극명한 사례',
            '해양생태계 및 어업에 장기간 심각한 영향'
        ],
        'sources': [
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf',
            'https://www.nifs.go.kr/page?id=red_tide_news',
            'https://www.kaosts.or.kr/conference/marine_heatwave_2024.pdf'
        ]
    },
    
    'event6': {
        'location': {'lat': 37.0, 'lon': 129.0},
        'area': '동해 중남부 해역 부근',
        'period': {'start_date': '2023-05-01', 'end_date': '2023-11-12'},
        'features': [
            '195일간 지속된 장기 해양열파',
            '2023년 동해 해역 주요 이벤트',
            '봄철부터 가을철까지 장기 지속',
            'event5와 연관된 광역 현상의 일부',
            '동해 고유 해양환경 변화 반영'
        ],
        'sources': [
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf',
            'https://www.kaosts.or.kr/conference/marine_heatwave_2024.pdf'
        ]
    },
    
    'event7': {
        'location': {'lat': 36.0, 'lon': 125.0},
        'area': '황해 남부 해역 부근',
        'period': {'start_date': '2024-07-01', 'end_date': '2024-07-21'},
        'features': [
            '21일간 지속된 해양열파',
            '황해 남쪽 경계 지역 발생',
            '여름철 집중 현상',
            '얕은 수심 특성으로 인한 빠른 승온',
            'event2와 연관된 황해 광역 현상'
        ],
        'sources': [
            'https://www.nifs.go.kr/page?id=red_tide_news',
            'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf'
        ]
    }
}

# 데이터베이스 요약 정보
database_summary = {
    'total_events': 7,
    'time_range': '2021-2024년',
    'max_duration': '268일 (event5)',
    'main_areas': ['동해', '황해', '동중국해'],
    'data_sources': [
        '해양기후예측센터',
        '국립수산과학원',
        'KAOSTS 학술대회',
        '기상청 기후정보포털'
    ],
    'criteria': '과거 30년 평균 대비 90백분위 초과, 5일 이상 지속',
    'highlights': [
        '주요 발생 해역: 동해 > 황해 > 동중국해 순',
        '기간 범위: 2021년~2024년',
        '검증 기준: 과거 30년 평균 대비 90백분위 초과하여 5일 이상 지속'
    ]
}

print("한반도 주변 해양열파 이벤트 데이터베이스 구축 완료")
print(f"총 {database_summary['total_events']}개 검증된 이벤트 포함")

# 데이터 접근 예시
print("\n=== 데이터 접근 예시 ===")
print(f"Event1 위치: 위도 {marine_heatwave_events['event1']['location']['lat']}, 경도 {marine_heatwave_events['event1']['location']['lon']}")
print(f"Event1 기간: {marine_heatwave_events['event1']['period']['start_date']} ~ {marine_heatwave_events['event1']['period']['end_date']}")
print(f"Event5 위치: 위도 {marine_heatwave_events['event5']['location']['lat']}, 경도 {marine_heatwave_events['event5']['location']['lon']}")
print(f"Event5 기간: {marine_heatwave_events['event5']['period']['start_date']} ~ {marine_heatwave_events['event5']['period']['end_date']}")

with open('Korean_sea_sst_MHW_event.json', 'w', encoding='utf-8') as file:
    json.dump(marine_heatwave_events, file, ensure_ascii=False, indent=4)
# Out:
# 한반도 주변 해양열파 이벤트 데이터베이스 구축 완료
# 총 7개 검증된 이벤트 포함
#
# === 데이터 접근 예시 ===
# Event1 위치: 위도 37.5, 경도 129.5
# Event1 기간: 2024-06-01 ~ 2024-11-11
# Event5 위치: 위도 35.0, 경도 128.0
# Event5 기간: 2023-04-15 ~ 2024-01-08

# %% [markdown]
# ## 해양열파 정보

# %%
import json

with open('Korean_sea_sst_MHW_event.json', 'r', encoding='utf-8') as file:
    KMHW = json.load(file)
    
KMHW['event1']
# Out:
# {'location': {'lat': 37.5, 'lon': 129.5},
#  'area': '동해 중부 해역 부근',
#  'period': {'start_date': '2024-06-01', 'end_date': '2024-11-11'},
#  'features': ['164일간 지속된 극한 해양열파',
#   '한반도 주변 2024년 최장 기록',
#   '여름철부터 가을철까지 지속',
#   '동해 전체 해역에 광범위하게 영향',
#   '수산업 및 해양생태계에 큰 영향'],
#  'sources': ['https://www.nifs.go.kr/page?id=red_tide_news',
#   'https://www.climate.go.kr/home/cc_data/2021/07/marine_heatwave.pdf']}

# %% [markdown]
# ## 한반도 주변 해역 위도, 경도

# %%
import json

# 해양수산부 1997년 공식 기준에 따른 한반도 주변 해역 정의
korea_seas = {
    # 남해 (South Sea)
    '남해': {
        'lat_range': [33.0, 35.47],    # 33°N ~ 35°28'N (해양수산부 동해-남해 경계)
        'lon_range': [124.0, 130.5],   # 서해 경계 ~ 한국 동쪽 연안
        'description': '남해 - 북위 35°28\' 이남의 한반도 남쪽 해역',
        'boundary_north': '35°28\'N (울산 태화강 하구 ~ 일본 이즈모시)',
        'boundary_west': '진도 서쪽 끝 ~ 제주도 차귀도 직선',
        'boundary_south': '제주도 우도 ~ 일본 후쿠에섬 직선'
    },
    
    # 동해 (East Sea)  
    '동해': {
        'lat_range': [35.47, 38.5],    # 35°28'N ~ 38.5°N
        'lon_range': [129.0, 132.0],   # 한국 동해안 ~ 동쪽 경계
        'description': '동해 - 북위 35°28\' 이북의 한반도 동쪽 해역',
        'boundary_south': '35°28\'N (울산 태화강 하구 ~ 일본 이즈모시)',
        'boundary_north': '두만강 하구',
        'boundary_west': '한반도 동해안선'
    },
    
    # 서해 (West Sea) = 황해 (Yellow Sea)
    '서해': {
        'lat_range': [33.5, 38.0],     # 33.5°N ~ 38°N  
        'lon_range': [124.0, 126.5],   # 서쪽 경계 ~ 한국 서해안
        'description': '서해(황해) - 한반도 서쪽 해역',
        'boundary_east': '진도 서쪽 끝 ~ 제주도 차귀도 직선 이북',
        'boundary_north': '압록강 하구',
        'official_name': 'Yellow Sea (국제 공식 명칭)'
    },
    
    # 전체 한반도 주변 해역
    '한반도': {
        'lat_range': [33.0, 38.5],     # 마라도 ~ 함북 경계
        'lon_range': [124.0, 132.0],   # 서단 ~ 동단
        'description': '한반도 전체 주변 해역',
        'total_area': '약 47만 km²'
    },

    # 전체 한반도 주변 해역
    '한반도확장': {
        'lat_range':  [33.0, 43.0],
        'lon_range': [122.0, 134.0],  
    },
    # 세부 해역 구분

    # 남해 세부 구역
    '남해주변': {
        'lat_range': [34.0, 35.47],
        'lon_range': [125.0, 129.5],
        'description': '남해안 연안 해역'
    },
    
    # 제주 주변 해역
    '제주주변': {
        'lat_range': [33.0, 34.0],
        'lon_range': [125.0, 127.5],
        'description': '제주도 주변 해역'
    },
    
    # 동해 북부
    '동해북부': {
        'lat_range': [37.0, 38.5],
        'lon_range': [129.0, 132.0],
        'description': '동해 북부 해역'
    },
    
    # 동해 남부
    '동해남부': {
        'lat_range': [35.47, 37.0],
        'lon_range': [129.0, 132.0],
        'description': '동해 남부 해역'
    },
    
    # 서해 북부
    '서해북부': {
        'lat_range': [36.5, 38.0],
        'lon_range': [124.0, 126.5],
        'description': '서해 북부 해역'
    },
    
    # 서해 남부
    '서해남부': {
        'lat_range': [33.5, 36.5],
        'lon_range': [124.0, 126.5],
        'description': '서해 남부 해역'
    },
    
    # 주요 경계 좌표
    'boundaries': {
        'east_south_boundary': 35.47,    # 35°28'N (동해-남해 경계)
        'west_south_boundary_lat': 33.27, # 진도-차귀도 직선 위도
        'marado_lat': 33.11,             # 마라도 (최남단)
        'dokdo_lat': 37.24,              # 독도
        'dokdo_lon': 131.87              # 독도
    },
    
    
    # 메타데이터
    'metadata': {
        'source': '해양수산부 1997년 공식 기준',
        'reference': '국립수산진흥원 1979년 한국해양편람',
        'coordinate_system': 'WGS84 (위도/경도)',
        'unit': 'degrees',
        'created_date': '2025-10-04',
        'note': '해양열파 분석을 위한 한반도 주변 해역 구분',
        'format': 'lat_range=[min, max], lon_range=[min, max]'
    }
}

with open('Korean_sea_lat_lon.json', 'w', encoding='utf-8') as file:
    json.dump(korea_seas, file, ensure_ascii=False, indent=4)

# %%
import json

with open('Korean_sea_lat_lon.json', 'r', encoding='utf-8') as file:
    KSEA = json.load(file)
    
KSEA['남해']
# Out:
# {'lat_range': [33.0, 35.47],
#  'lon_range': [124.0, 130.5],
#  'description': "남해 - 북위 35°28' 이남의 한반도 남쪽 해역",
#  'boundary_north': "35°28'N (울산 태화강 하구 ~ 일본 이즈모시)",
#  'boundary_west': '진도 서쪽 끝 ~ 제주도 차귀도 직선',
#  'boundary_south': '제주도 우도 ~ 일본 후쿠에섬 직선'}
