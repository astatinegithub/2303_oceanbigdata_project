# %%
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import pandas as pd
import netCDF4 as nc
import xarray as xr

# %%
# pip install mhw-detect
import Libraries.marineHeatWaves as mhw

# %matplotlib inline

# %%
path = "D:/Repositories/too_much_big_data/" + 'NOAA_SST_KoreanPeninsula_1981-2025_FULL.nc'
data = nc.Dataset(path)
# 결과: ds.sst(time, lat, lon)
data
# Out:
# <class 'netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.5
#     title: NOAA SST Korean Peninsula Region (1981-2025)
#     institution: NOAA/NCDC
#     source: NOAA/NCDC  ftp://eclipse.ncdc.noaa.gov/pub/OI-daily-v2/
#     history: Thu Aug 24 13:34:17 2017: ncatted -O -a References,global,d,, sst.day.mean.1981.v2.nc
# Version 1.0
#     dataset_title: NOAA Daily Optimum Interpolation Sea Surface Temperature
#     References: https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2.highres.html
#     comment: Reynolds, et al.(2007) Daily High-Resolution-Blended Analyses for Sea Surface Temperature (available at https://doi.org/10.1175/2007JCLI1824.1). Banzon, et al.(2016) A long-term record of blended satellite and in situ sea-surface temperature for climate monitoring, modeling and environmental studies (available at https://doi.org/10.5194/essd-8-165-2016). Huang, B., C. Liu, V. Banzon, E. Freeman, G. Graham, B. Hankins, T. Smith, and H.-M. Zhang, 2021: Improvements of the Daily Optimum Interpolation Sea Surface Temperature (DOISST) Version 2.1 (available at https://doi.org/10.1175/JCLI-D-20-0166.1). Anomaly is based on 1971-2000 OI.v2 SST. Satellite data: multi-satellite sensor (AVHRR+VIIRS) data. Ice data: NCEP Ice and GSFC Ice. Data less than 15 days old may be subject to revision.
#     description: Daily Sea Surface Temperature data extracted for Korean Peninsula region
#     spatial_coverage: Lat: 30.0-45.0°N, Lon: 120.0-135.0°E
#     created_date: 2025-09-24 09:18:01
#     creator: Korean Peninsula SST Analysis
#     dimensions(sizes): time(16085), lat(60), lon(60)
#     variables(dimensions): float32 sst(time, lat, lon), float64 time(time), float32 lat(lat), float32 lon(lon)
#     groups:

# %%
ds = xr.open_dataset(path)
sst = ds['sst']
sst.sel(time='2011-01-01', lat=30.125, lon=120.625).values
# Out:
# ['2011-01-01', '2011-01-02', '2011-01-03', '2011-01-04', '2011-01-05', '2011-01-06', '2011-01-07', '2011-01-08', '2011-01-09']

# %%
from datetime import datetime, timedelta

start_date = datetime(1982, 1, 1)
end_date = datetime(2024, 1, 1)

year_list = []

current_date = start_date
while current_date <= end_date:
    formatted_date = current_date.strftime(f"%Y-{"%m".zfill(2)}-{"%d".zfill(2)}")
    year_list.append(formatted_date)
    current_date += timedelta(days=1)

# %%
ds = xr.open_dataset(path)
sst = ds['sst']
test = sst.sel(time=year_list, lat=30.125, lon=120.625).values

plt.figure(figsize=(18, 4))
plt.plot(test)
